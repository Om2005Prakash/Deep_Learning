# %% [markdown]
# # Neural Network from Scratch
#
# #### Tensorflow is only used for loading DATASET

# %%
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2024-06-28 21:32:09.199886: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-28 21:32:09.199917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-28 21:32:09.200796: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-28 21:32:09.205564: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-28 21:32:09.714274: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def one_hot(x, depth):
    res=[]
    for i in range(len(x)):
        tmp = [0 for i in range(depth)]
        tmp[x[i]] = 1
        tmp = np.array(tmp)
        res.append(tmp)
    res = np.array(res)
    return res

# %%
(train_data, train_label), (test_data, test_label) =mnist.load_data()

train_data = train_data.reshape((60000, 28*28))
test_data = test_data.reshape((10000, 28*28))

test_label = one_hot(test_label, 10)
train_label = one_hot(train_label, 10)

# %%
train_data = train_data / 255

# %%
class Input():
    def __init__(self, shape):
        self.type = "Input"
        self.shape = shape
        
    def operate(self, x):
        self.Z = np.array(x, copy=True)
        return self.Z
        
class Dense():
    def __init__(self, shape, prev):
        self.type = "Dense"
        self.shape = shape
        self.prev = prev
        self.W = np.random.uniform(-.5, .5, size=(self.shape, self.prev.shape))
        self.B = np.random.uniform(-.5, .5,size=self.shape)
        self.grad_W = np.zeros((self.shape, self.prev.shape))
        self.grad_Z = np.zeros(self.prev.shape)
        self.grad_B = np.zeros(shape)
        
    def operate(self, x):
        self.Z = np.matmul(self.W, x) + self.B
        return relu(self.Z)
    
    def ret(self, x):
        return self.Z

class Output():
    def __init__(self, shape, prev):
        self.type = "Output"
        self.shape = shape
        self.prev = prev
        self.W = np.random.uniform(-.5, .5, size=(self.shape, self.prev.shape))
        self.B = np.random.uniform(-.5, .5,size=self.shape)
        self.grad_W = np.zeros((self.shape, self.prev.shape))
        self.grad_Z = np.zeros(self.prev.shape)
        self.grad_B = np.zeros(shape)
        self.grad_loss = np.zeros(shape)
        
    def operate(self, x):
        self.Z = np.matmul(self.W, x) + self.B
        return softmax(self.Z)
    
    def ret(self, x):
        return self.Z

# %%
def relu(x):
    return np.maximum(0,x)

def softmax(X):
    Z = X - np.max(X)
    return np.exp(Z)/(np.sum(np.exp(Z), axis=0))

def grad_Z(w, z_curr, z_prev, dz_next, act):        #Calculating dLoss wrt dz_prev
    grad = np.zeros(z_prev.shape)
    if act == "relu":
        for i in range(z_prev.shape[0]):
            for j in range(z_curr.shape[0]):
                if z_curr[j] > 0:                   #coz dReLU/dZ whould be zero
                    grad[i] += dz_next[j]*1*w[j][i]
    elif act == "softmax":
        for i in range(z_prev.shape[0]):
            for j in range(z_curr.shape[0]):
                for k in range(dz_next.shape[0]):
                    if k == j:
                        grad[i] += dz_next[k]*(softmax(z_curr)[k] - (softmax(z_curr)[k])**2)*w[j][i]
                    else:
                        grad[i] += dz_next[k]*(-1 * softmax(z_curr)[j] * softmax(z_curr)[k])*w[j][i]
    return grad
    
def grad_W(w, z_curr, z_prev, dz_next, act):         # Z = matmul(W,Z_prev) + B
    grad = np.zeros(w.shape)
    if act == "relu":
        for j in range(w.shape[0]):
            if z_curr[j] > 0:                       #coz dReLU/dZ whould be zero
                for i in range(w.shape[1]):
                    grad[j][i] = dz_next[j]*1*z_prev[i]
    elif act == "softmax":
        for j in range(w.shape[0]):
            for i in range(w.shape[1]):
                for k in range(dz_next.shape[0]):
                    if j == k:
                        grad[j][i] += dz_next[k]*(softmax(z_curr)[k] - (softmax(z_curr)[k])**2)*z_prev[i]
                    else:
                        grad[j][i] += dz_next[k]*(-1 * softmax(z_curr)[j] * softmax(z_curr)[k])*z_prev[i]
    return grad

def grad_B(b, z_curr, dz_next, act):
    grad = np.zeros(b.shape)
    if act == "relu":
        for j in range(b.shape[0]):
            if z_curr[j] > 0:                       #coz dReLU/dZ whould be zero
                grad[j] =  dz_next[j] * 1 * 1
    elif act == "softmax":
        for j in range(b.shape[0]):
            for k in range(dz_next.shape[0]):
                if j == k:
                    grad[j] += dz_next[k]*(softmax(z_curr)[k] - (softmax(z_curr)[k])**2)*1
                else:
                    grad[j] += dz_next[k]*(-1 * softmax(z_curr)[j] * softmax(z_curr)[k])*1
    return grad

# %%
class model():
    def __init__(self):
        self.step_size = 0.01
        self.epochs = 2
        self.m = 32
        self.batch_acc = []
    
    def make(self, inputs, outputs, optimizer):
        self.comp_graph = []
        self.input_layer = inputs
        self.output_layer = outputs
        i = outputs
        while i.type != "Input":
            self.comp_graph.append(i)
            i=i.prev
        
        if (optimizer == "adam"):
            self.adam_init()
            self.optimizer = self.adam
        elif (optimizer == "RMSprop"):
            self.RMSprop_init()
            self.optimizer = self.RMSprop
        else:
            self.step_size = 0.01
            self.optimizer = self.SGD
            
    def SGD(self, x, grad, layer, sub_typ):
        return (x - self.step_size*grad)
        
    def adam_init(self):
        #Hyper Parameters
        self.a = 0.1
        self.b1 = 0.9
        self.b2 = 0.999
        self.e = 10e-8
        
        #t, m, v STORING THE HISTORY
        self.pram = {i:{'W':{'t':0, 'm':np.zeros(i.W.shape), 'v':np.zeros(i.W.shape)},
                        'B':{'t':0, 'm':np.zeros(i.B.shape), 'v':np.zeros(i.B.shape)}} for i in self.comp_graph}
        
    def adam(self, x, grad, layer, sub_typ):
        self.pram[layer][sub_typ]['t'] += 1
        self.pram[layer][sub_typ]['m'] = self.b1 * self.pram[layer][sub_typ]['m'] + (1-self.b1) * (np.power(grad,1))
        self.pram[layer][sub_typ]['v'] = self.b2 * self.pram[layer][sub_typ]['v'] + (1-self.b2) * (np.power(grad,2))
        corr_m = self.pram[layer][sub_typ]['m']/(1 - np.power(self.b1, self.pram[layer][sub_typ]['t']))
        corr_v = self.pram[layer][sub_typ]['v']/(1 - np.power(self.b2, self.pram[layer][sub_typ]['t']))
        x = x - self.a * (corr_m/(np.add(np.power(corr_v, 0.5), self.e)))
        return x
            
    def RMSprop_init(self):
        self.a = 0.1
        self.b1 = 0.9
        self.b2 = 0.999
        self.e = 10e-8
        self.pram = {i:{'W':{'t':0, 'v':np.zeros(i.W.shape)},
                        'B':{'t':0, 'v':np.zeros(i.B.shape)}} for i in self.comp_graph}
        
    def RMSprop(self, x, grad, layer, sub_typ):
        self.pram[layer][sub_typ]['t'] += 1
        self.pram[layer][sub_typ]['v'] = self.b2 * self.pram[layer][sub_typ]['v'] + (1-self.b2) * (np.power(grad,2))
        x = x - self.a * (grad/(np.add(np.power(self.pram[layer][sub_typ]['v'], 0.5), self.e)))
        return x
        
    def fit(self, X, Y):
        
        Y.flags.writeable = False
        X.flags.writeable = False
        correct_pred = 0

        for i in range(len(X)):
            #forward pass
            i_copy = i
            i = i%self.m
            
            x = self.input_layer.operate(X[i])
            for j in range(-1, -1*len(self.comp_graph)-1, -1):
                x = self.comp_graph[j].operate(x)

            if np.argmax(x) == np.argmax(Y[i]):
                correct_pred += 1

            for e in range(self.epochs):
                #backward pass
                #Signatures
                #grad_W(w, z_curr, z_prev, dz_next, act)
                #grad_B(b, z_curr, dz_next, act)
                self.output_layer.grad_loss = (-2)*(Y[i] - softmax(self.output_layer.Z))/len(Y[i])
                
                self.output_layer.grad_W = grad_W(self.output_layer.W, self.output_layer.Z,
                                                  self.output_layer.prev.Z, self.output_layer.grad_loss, "softmax")
                
                self.output_layer.grad_Z = grad_Z(self.output_layer.W, self.output_layer.Z,
                                                  self.output_layer.prev.Z, self.output_layer.grad_loss, "softmax")
                
                self.output_layer.grad_B = grad_B(self.output_layer.B,
                                                  self.output_layer.Z ,self.output_layer.grad_loss, "softmax")
 
                self.output_layer.W = self.optimizer(self.output_layer.W, self.output_layer.grad_W,
                                                     self.output_layer, "W")
                self.output_layer.B = self.optimizer(self.output_layer.B, self.output_layer.grad_B,
                                                     self.output_layer, "B")
                    
                self.comp_graph.append(self.comp_graph[-1].prev) #Quick Fix, Don't Look Here :-D
                
                for k in range(1, len(self.comp_graph)-1):
                    self.comp_graph[k].grad_W = grad_W(self.comp_graph[k].W, self.comp_graph[k].Z,
                                                       self.comp_graph[k+1].Z, self.comp_graph[k-1].grad_Z, "relu")
                    
                    self.comp_graph[k].grad_Z = grad_Z(self.comp_graph[k].W, self.comp_graph[k].Z,
                                                       self.comp_graph[k+1].Z, self.comp_graph[k-1].grad_Z, "relu")
                    
                    self.comp_graph[k].grad_B = grad_B(self.comp_graph[k].B,
                                                       self.comp_graph[k].Z, self.comp_graph[k-1].grad_Z, "relu")

                    self.comp_graph[k].W = self.optimizer(self.comp_graph[k].W, self.comp_graph[k].grad_W,
                                                     self.comp_graph[k], "W")
                    self.comp_graph[k].B = self.optimizer(self.comp_graph[k].B, self.comp_graph[k].grad_B,
                                                     self.comp_graph[k], "B")
                
                self.comp_graph.pop(-1)                         #Quick Fix, Don't Look Here :-D
            
            i = i_copy
            if (i%32 == 0):
                self.batch_acc.append(correct_pred/32)
                print(correct_pred/32, "Total Processed", i)
                correct_pred = 0
    
    def predict (self, X):
        x = self.input_layer.operate(X)
        for i in range(-1, -1*len(self.comp_graph)-1, -1):
            x = self.comp_graph[i].operate(x)
        return x

# %%
'''
For adding new layer just put the "output size" the input size 
will be ajusted automatically from the prev layer output
'''

inputs = Input(28*28)
x = Dense(28*2 ,inputs)
outputs = Output(10 ,x)

digit_classifier = model()

# %% [markdown]
# # Testing SGD, RMSprop and Adam with same weights initialization
# ##### SGD doesn't learn well with small steps but Adam works well with small steps

# %%
inputs = Input(28*28)
x = Dense(28*2 ,inputs)
outputs = Output(10 ,x)

digit_classifier = model()

x_W = x.W
x_B = x.B

outputs_W = outputs.W
outputs_B = outputs.B

# %%
# SGD

digit_classifier.make(inputs=inputs, outputs=outputs, optimizer="SGD")
digit_classifier.step_size = 0.1      #Step size if you are using SGD
digit_classifier.epochs = 1           #No of Epochs
digit_classifier.a = 0.001            #Step size if you are using Adam
digit_classifier.m = 9999999          #This will repeat the images starting from image 0 to m-1 in train set
                                      #This heps me to check if the model is atleast overfitting

digit_classifier.fit(train_data[:3200], train_label[:3200])
# Out:
# 0.0 Total Processed 0
# 0.09375 Total Processed 32
# 0.09375 Total Processed 64
# 0.03125 Total Processed 96
# 0.21875 Total Processed 128
# 0.09375 Total Processed 160
# 0.25 Total Processed 192
# 0.34375 Total Processed 224
# 0.34375 Total Processed 256
# 0.40625 Total Processed 288
# 0.375 Total Processed 320
# 0.40625 Total Processed 352
# 0.5 Total Processed 384
# 0.53125 Total Processed 416
# 0.375 Total Processed 448
# 0.46875 Total Processed 480
# 0.5 Total Processed 512
# 0.25 Total Processed 544
# 0.375 Total Processed 576
# 0.3125 Total Processed 608
# 0.4375 Total Processed 640
# 0.40625 Total Processed 672
# 0.5 Total Processed 704
# 0.4375 Total Processed 736
# 0.5 Total Processed 768
# 0.4375 Total Processed 800
# 0.5 Total Processed 832
# 0.40625 Total Processed 864
# 0.4375 Total Processed 896
# 0.65625 Total Processed 928
# 0.53125 Total Processed 960
# 0.5625 Total Processed 992
# 0.625 Total Processed 1024
# 0.625 Total Processed 1056
# 0.59375 Total Processed 1088
# 0.6875 Total Processed 1120
# 0.5625 Total Processed 1152
# 0.6875 Total Processed 1184
# 0.59375 Total Processed 1216
# 0.625 Total Processed 1248
# 0.625 Total Processed 1280
# 0.625 Total Processed 1312
# 0.625 Total Processed 1344
# 0.5625 Total Processed 1376
# 0.625 Total Processed 1408
# 0.5 Total Processed 1440
# 0.71875 Total Processed 1472
# 0.78125 Total Processed 1504
# 0.5625 Total Processed 1536
# 0.65625 Total Processed 1568
# 0.65625 Total Processed 1600
# 0.71875 Total Processed 1632
# 0.625 Total Processed 1664
# 0.78125 Total Processed 1696
# 0.8125 Total Processed 1728
# 0.71875 Total Processed 1760
# 0.84375 Total Processed 1792
# 0.59375 Total Processed 1824
# 0.75 Total Processed 1856
# 0.6875 Total Processed 1888
# 0.875 Total Processed 1920
# 0.6875 Total Processed 1952
# 0.59375 Total Processed 1984
# 0.625 Total Processed 2016
# 0.65625 Total Processed 2048
# 0.59375 Total Processed 2080
# 0.78125 Total Processed 2112
# 0.6875 Total Processed 2144
# 0.90625 Total Processed 2176
# 0.65625 Total Processed 2208
# 0.71875 Total Processed 2240
# 0.78125 Total Processed 2272
# 0.65625 Total Processed 2304
# 0.78125 Total Processed 2336
# 0.71875 Total Processed 2368
# 0.71875 Total Processed 2400
# 0.6875 Total Processed 2432
# 0.8125 Total Processed 2464
# 0.9375 Total Processed 2496
# 0.96875 Total Processed 2528
# 0.78125 Total Processed 2560
# 0.8125 Total Processed 2592
# 0.71875 Total Processed 2624
# 0.8125 Total Processed 2656
# 0.78125 Total Processed 2688
# 0.6875 Total Processed 2720
# 0.6875 Total Processed 2752
# 0.75 Total Processed 2784
# 0.75 Total Processed 2816
# 0.71875 Total Processed 2848
# 0.875 Total Processed 2880
# 0.6875 Total Processed 2912
# 0.8125 Total Processed 2944
# 0.8125 Total Processed 2976
# 0.78125 Total Processed 3008
# 0.75 Total Processed 3040
# 0.75 Total Processed 3072
# 0.8125 Total Processed 3104
# 0.78125 Total Processed 3136
# 0.78125 Total Processed 3168

# %% [markdown]
# ##          Testing on ALL 10,000 samples in test set for SGD

# %%
correct_count = 0

for i in range(len(test_data)):
    if np.argmax(digit_classifier.predict(test_data[i])) == np.argmax(test_label[i]):
        correct_count += 1
print(f"Accuracy: {correct_count/len(test_data)}")
# Out:
# Accuracy: 0.7745

# %%
SGD_performance = digit_classifier.batch_acc
digit_classifier.batch_acc = []

x.W = x_W
x.B = x_B

outputs.W = outputs_W
outputs.B = outputs_B

# %%
# Adam

digit_classifier.make(inputs=inputs, outputs=outputs, optimizer="adam")
digit_classifier.step_size = 0.001
digit_classifier.epochs = 1
digit_classifier.a = 0.001
digit_classifier.m = 9999999

digit_classifier.fit(train_data[:3200], train_label[:3200])
# Out:
# 0.0 Total Processed 0
# 0.09375 Total Processed 32
# 0.15625 Total Processed 64
# 0.09375 Total Processed 96
# 0.3125 Total Processed 128
# 0.1875 Total Processed 160
# 0.28125 Total Processed 192
# 0.5 Total Processed 224
# 0.53125 Total Processed 256
# 0.5 Total Processed 288
# 0.59375 Total Processed 320
# 0.46875 Total Processed 352
# 0.59375 Total Processed 384
# 0.65625 Total Processed 416
# 0.625 Total Processed 448
# 0.46875 Total Processed 480
# 0.5625 Total Processed 512
# 0.375 Total Processed 544
# 0.46875 Total Processed 576
# 0.46875 Total Processed 608
# 0.625 Total Processed 640
# 0.6875 Total Processed 672
# 0.5 Total Processed 704
# 0.53125 Total Processed 736
# 0.65625 Total Processed 768
# 0.6875 Total Processed 800
# 0.625 Total Processed 832
# 0.53125 Total Processed 864
# 0.59375 Total Processed 896
# 0.65625 Total Processed 928
# 0.59375 Total Processed 960
# 0.75 Total Processed 992
# 0.78125 Total Processed 1024
# 0.6875 Total Processed 1056
# 0.65625 Total Processed 1088
# 0.71875 Total Processed 1120
# 0.59375 Total Processed 1152
# 0.78125 Total Processed 1184
# 0.71875 Total Processed 1216
# 0.625 Total Processed 1248
# 0.6875 Total Processed 1280
# 0.78125 Total Processed 1312
# 0.78125 Total Processed 1344
# 0.65625 Total Processed 1376
# 0.78125 Total Processed 1408
# 0.65625 Total Processed 1440
# 0.71875 Total Processed 1472
# 0.78125 Total Processed 1504
# 0.625 Total Processed 1536
# 0.6875 Total Processed 1568
# 0.8125 Total Processed 1600
# 0.71875 Total Processed 1632
# 0.6875 Total Processed 1664
# 0.8125 Total Processed 1696
# 0.875 Total Processed 1728
# 0.78125 Total Processed 1760
# 0.8125 Total Processed 1792
# 0.75 Total Processed 1824
# 0.78125 Total Processed 1856
# 0.78125 Total Processed 1888
# 0.84375 Total Processed 1920
# 0.84375 Total Processed 1952
# 0.75 Total Processed 1984
# 0.75 Total Processed 2016
# 0.75 Total Processed 2048
# 0.71875 Total Processed 2080
# 0.8125 Total Processed 2112
# 0.8125 Total Processed 2144
# 0.96875 Total Processed 2176
# 0.78125 Total Processed 2208
# 0.84375 Total Processed 2240
# 0.78125 Total Processed 2272
# 0.8125 Total Processed 2304
# 0.875 Total Processed 2336
# 0.78125 Total Processed 2368
# 0.78125 Total Processed 2400
# 0.65625 Total Processed 2432
# 0.84375 Total Processed 2464
# 0.875 Total Processed 2496
# 0.9375 Total Processed 2528
# 0.8125 Total Processed 2560
# 0.84375 Total Processed 2592
# 0.78125 Total Processed 2624
# 0.8125 Total Processed 2656
# 0.78125 Total Processed 2688
# 0.78125 Total Processed 2720
# 0.71875 Total Processed 2752
# 0.8125 Total Processed 2784
# 0.84375 Total Processed 2816
# 0.90625 Total Processed 2848
# 0.875 Total Processed 2880
# 0.75 Total Processed 2912
# 0.84375 Total Processed 2944
# 0.875 Total Processed 2976
# 0.90625 Total Processed 3008
# 0.75 Total Processed 3040
# 0.84375 Total Processed 3072
# 0.84375 Total Processed 3104
# 0.90625 Total Processed 3136
# 0.875 Total Processed 3168

# %% [markdown]
# # Testing on all 10,000 samples in Test dataset

# %%
correct_count = 0

for i in range(len(test_data)):
    if np.argmax(digit_classifier.predict(test_data[i])) == np.argmax(test_label[i]):
        correct_count += 1
print(f"Accuracy: {correct_count/len(test_data)}")
# Out:
# Accuracy: 0.8384

# %%
Adam_performance = digit_classifier.batch_acc
digit_classifier.batch_acc = []

x.W = x_W
x.B = x_B

outputs.W = outputs_W
outputs.B = outputs_B

# %%
# RMSprop

digit_classifier.make(inputs=inputs, outputs=outputs, optimizer="RMSprop")
digit_classifier.step_size = 0.001
digit_classifier.epochs = 1
digit_classifier.a = 0.001
digit_classifier.m = 9999999

digit_classifier.fit(train_data[:3200], train_label[:3200])

RMSprop_performance = digit_classifier.batch_acc
digit_classifier.batch_acc = []
# Out:
# 0.0 Total Processed 0
# 0.1875 Total Processed 32
# 0.0625 Total Processed 64
# 0.28125 Total Processed 96
# 0.34375 Total Processed 128
# 0.15625 Total Processed 160
# 0.4375 Total Processed 192
# 0.125 Total Processed 224
# 0.21875 Total Processed 256
# 0.25 Total Processed 288
# 0.34375 Total Processed 320
# 0.25 Total Processed 352
# 0.5625 Total Processed 384
# 0.4375 Total Processed 416
# 0.34375 Total Processed 448
# 0.34375 Total Processed 480
# 0.3125 Total Processed 512
# 0.25 Total Processed 544
# 0.40625 Total Processed 576
# 0.46875 Total Processed 608
# 0.375 Total Processed 640
# 0.375 Total Processed 672
# 0.53125 Total Processed 704
# 0.375 Total Processed 736
# 0.3125 Total Processed 768
# 0.3125 Total Processed 800
# 0.375 Total Processed 832
# 0.4375 Total Processed 864
# 0.34375 Total Processed 896
# 0.5625 Total Processed 928
# 0.46875 Total Processed 960
# 0.5 Total Processed 992
# 0.34375 Total Processed 1024
# 0.5 Total Processed 1056
# 0.4375 Total Processed 1088
# 0.46875 Total Processed 1120
# 0.40625 Total Processed 1152
# 0.6875 Total Processed 1184
# 0.59375 Total Processed 1216
# 0.4375 Total Processed 1248
# 0.625 Total Processed 1280
# 0.40625 Total Processed 1312
# 0.46875 Total Processed 1344
# 0.4375 Total Processed 1376
# 0.53125 Total Processed 1408
# 0.46875 Total Processed 1440
# 0.53125 Total Processed 1472
# 0.5 Total Processed 1504
# 0.46875 Total Processed 1536
# 0.53125 Total Processed 1568
# 0.46875 Total Processed 1600
# 0.5 Total Processed 1632
# 0.53125 Total Processed 1664
# 0.5625 Total Processed 1696
# 0.59375 Total Processed 1728
# 0.53125 Total Processed 1760
# 0.375 Total Processed 1792
# 0.59375 Total Processed 1824
# 0.53125 Total Processed 1856
# 0.46875 Total Processed 1888
# 0.4375 Total Processed 1920
# 0.53125 Total Processed 1952
# 0.5625 Total Processed 1984
# 0.5 Total Processed 2016
# 0.5 Total Processed 2048
# 0.4375 Total Processed 2080
# 0.5 Total Processed 2112
# 0.46875 Total Processed 2144
# 0.46875 Total Processed 2176
# 0.53125 Total Processed 2208
# 0.46875 Total Processed 2240
# 0.53125 Total Processed 2272
# 0.65625 Total Processed 2304
# 0.71875 Total Processed 2336
# 0.59375 Total Processed 2368
# 0.5 Total Processed 2400
# 0.625 Total Processed 2432
# 0.65625 Total Processed 2464
# 0.4375 Total Processed 2496
# 0.53125 Total Processed 2528
# 0.5625 Total Processed 2560
# 0.53125 Total Processed 2592
# 0.5 Total Processed 2624
# 0.59375 Total Processed 2656
# 0.71875 Total Processed 2688
# 0.6875 Total Processed 2720
# 0.5 Total Processed 2752
# 0.625 Total Processed 2784
# 0.71875 Total Processed 2816
# 0.625 Total Processed 2848
# 0.71875 Total Processed 2880
# 0.59375 Total Processed 2912
# 0.625 Total Processed 2944
# 0.65625 Total Processed 2976
# 0.71875 Total Processed 3008
# 0.65625 Total Processed 3040
# 0.5 Total Processed 3072
# 0.78125 Total Processed 3104
# 0.65625 Total Processed 3136
# 0.8125 Total Processed 3168

# %% [markdown]
# # Testing on all 10,000 samples in Test dataset

# %%
correct_count = 0

for i in range(len(test_data)):
    if np.argmax(digit_classifier.predict(test_data[i])) == np.argmax(test_label[i]):
        correct_count += 1
print(f"Accuracy: {correct_count/len(test_data)}")
# Out:
# Accuracy: 0.6471

# %% [markdown]
# # Performance SGD vs RMSprop vs Adam

# %%
plt.figure(figsize=(10, 3))
plt.plot(range(len(SGD_performance)), SGD_performance, 'b--', label = "SGD")
plt.plot(range(len(Adam_performance)), Adam_performance, 'g-', label = "Adam")
plt.plot(range(len(RMSprop_performance)), RMSprop_performance, 'r--', label = "RMSprop")
plt.legend()
plt.show()

# %%
'''
Do not execute this cell. Basically i did a "quick fix" in the BackProp, sometimes if the code is intruptted in
the BackProp then we need to manually remove the input layer from the comp_graph so we can run the code without
reinitializing the weights
'''
digit_classifier.comp_graph.pop(-1)
